# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#1EB182;"><img src="../../images/icon102.png" width="38px"></img> **Hopsworks Feature Store** </span><span style="font-width:bold; font-size: 3rem; color:#333;">- Part 02: Feature Pipeline</span>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/logicalclocks/hopsworks-tutorials/blob/master/advanced_tutorials/air_quality/2_feature_pipeline.ipynb)
#
#
# ## 🗒️ This notebook is divided into the following sections:
# 1. Parse Data
# 2. Feature Group Insertion

# %% [markdown]
# ### <span style='color:#ff5f27'> 📝 Imports

# %%
import datetime
import time
import requests
import pandas as pd
import json

from functions import *

import warnings
warnings.filterwarnings("ignore")

# %%
with open('target_cities.json') as json_file:
    target_cities = json.load(json_file)

# %%
today = datetime.date.today()
forecast_day = today + datetime.timedelta(days=7)
hindcast_day = today - datetime.timedelta(days=10)

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:#ff5f27'> 🌫 Filling gaps in Air Quality data (PM2.5)</span>

# %% [markdown]
# ### First time we will determine the 'last update date' using our backfill data
# #### Next time we will use `feature view` method from Hopsworks Feature Store

# %% [markdown]
# ### <span style='color:#ff5f27'>  🧙🏼‍♂️ Parsing PM2.5 data

# %%
start_of_cell = time.time()

df_aq_raw = pd.DataFrame()

for continent in target_cities:
    for city_name, coords in target_cities[continent].items():
        df_ = get_aqi_data_from_open_meteo(city_name=city_name,
                                           coordinates=coords,
                                           start_date=str(hindcast_day),
                                           end_date=str(today))
        df_aq_raw = pd.concat([df_aq_raw, df_]).reset_index(drop=True)
    
end_of_cell = time.time()
print("-" * 64)
print(f"Parsed new PM2.5 data for ALL locations up to {str(today)}.")
print(f"Took {round(end_of_cell - start_of_cell, 2)} sec.\n")
# Out:
# Processed PM2_5 for Amsterdam since 2023-06-02 till 2023-06-12.
# Took 0.21 sec.
#
# Processed PM2_5 for Athina since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Berlin since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Gdansk since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Kraków since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for London since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Madrid since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Marseille since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Milano since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for München since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Napoli since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Paris since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Sevilla since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Stockholm since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Tallinn since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Varna since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Wien since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Albuquerque since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Atlanta since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Chicago since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Columbus since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Dallas since 2023-06-02 till 2023-06-12.
# Took 0.18 sec.
#
# Processed PM2_5 for Denver since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Houston since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Los Angeles since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for New York since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Phoenix-Mesa since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Salt Lake City since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for San Francisco since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Tampa since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Bellevue-SE 12th St since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for DARRINGTON - FIR ST (Darrington High School) since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for KENT - JAMES & CENTRAL since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for LAKE FOREST PARK TOWNE CENTER since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for MARYSVILLE - 7TH AVE (Marysville Junior High) since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for NORTH BEND - NORTH BEND WAY since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for SEATTLE - BEACON HILL since 2023-06-02 till 2023-06-12.
# Took 0.22 sec.
#
# Processed PM2_5 for SEATTLE - DUWAMISH since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for SEATTLE - SOUTH PARK #2 since 2023-06-02 till 2023-06-12.
# Took 0.18 sec.
#
# Processed PM2_5 for Seattle-10th & Weller since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for TACOMA - ALEXANDER AVE since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for TACOMA - L STREET since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# Processed PM2_5 for Tacoma-S 36th St since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Tukwila Allentown since 2023-06-02 till 2023-06-12.
# Took 0.16 sec.
#
# Processed PM2_5 for Tulalip-Totem Beach Rd since 2023-06-02 till 2023-06-12.
# Took 0.17 sec.
#
# ----------------------------------------------------------------
# Parsed new PM2.5 data for ALL locations up to 2023-06-12.
# Took 7.59 sec.

# %%
df_aq_raw
# Out:
#                   city_name        date  pm2_5
# 0                 Amsterdam  2023-06-02    6.5
# 1                 Amsterdam  2023-06-03    5.7
# 2                 Amsterdam  2023-06-04    6.4
# 3                 Amsterdam  2023-06-05    6.7
# 4                 Amsterdam  2023-06-06    7.0
# ..                      ...         ...    ...
# 490  Tulalip-Totem Beach Rd  2023-06-08   20.4
# 491  Tulalip-Totem Beach Rd  2023-06-09   11.0
# 492  Tulalip-Totem Beach Rd  2023-06-10   12.7
# 493  Tulalip-Totem Beach Rd  2023-06-11   12.7
# 494  Tulalip-Totem Beach Rd  2023-06-12   21.0
#
# [495 rows x 3 columns]

# %%
df_aq_update = df_aq_raw
df_aq_update
# Out:
#                   city_name        date  pm2_5
# 0                 Amsterdam  2023-06-02    6.5
# 1                 Amsterdam  2023-06-03    5.7
# 2                 Amsterdam  2023-06-04    6.4
# 3                 Amsterdam  2023-06-05    6.7
# 4                 Amsterdam  2023-06-06    7.0
# ..                      ...         ...    ...
# 490  Tulalip-Totem Beach Rd  2023-06-08   20.4
# 491  Tulalip-Totem Beach Rd  2023-06-09   11.0
# 492  Tulalip-Totem Beach Rd  2023-06-10   12.7
# 493  Tulalip-Totem Beach Rd  2023-06-11   12.7
# 494  Tulalip-Totem Beach Rd  2023-06-12   21.0
#
# [495 rows x 3 columns]

# %% [markdown]
# ### <span style="color:#ff5f27;">🛠 Feature Engineering PM2.5</span>

# %%
df_aq_update['date'] = pd.to_datetime(df_aq_update['date'])

# %%
# df_aq_update = feature_engineer_aq(df_aq_update)
df_aq_update = df_aq_update.dropna()

# %%
df_aq_update.isna().sum().sum()
# Out:
# 0

# %%
df_aq_update.shape
# Out:
# (495, 3)

# %%
df_aq_update.columns
# Out:
# Index(['city_name', 'date', 'pm2_5'], dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ### <span style='color:#ff5f27'>  🧙🏼‍♂️ Parsing Weather data

# %%
start_of_cell = time.time()

df_weather_update = pd.DataFrame()


for city_name, coords in target_cities["US"].items():
    df_ = get_weather_data_from_open_meteo(city_name=city_name,
                                           coordinates=coords,
                                           start_date=str(today),
                                           end_date=str(forecast_day),
                                           forecast=True)
    df_weather_update = pd.concat([df_weather_update, df_]).reset_index(drop=True)


for continent in target_cities:
    for city_name, coords in target_cities[continent].items():
        df_ = get_weather_data_from_open_meteo(city_name=city_name,
                                               coordinates=coords,
                                               start_date=str(today),
                                               end_date=str(forecast_day),
                                               forecast=True)
        df_weather_update = pd.concat([df_weather_update, df_]).reset_index(drop=True)
    
end_of_cell = time.time()
print("-" * 64)
print(f"Parsed new weather data for ALL cities up to {str(today)}.")
print(f"Took {round(end_of_cell - start_of_cell, 2)} sec.\n")
# Out:
# Parsed weather for Albuquerque since 2023-06-12 till 2023-06-19.
# Took 0.17 sec.
#
# Parsed weather for Atlanta since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for Chicago since 2023-06-12 till 2023-06-19.
# Took 0.21 sec.
#
# Parsed weather for Columbus since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Dallas since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for Denver since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for Houston since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for Los Angeles since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for New York since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Phoenix-Mesa since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for Salt Lake City since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for San Francisco since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for Tampa since 2023-06-12 till 2023-06-19.
# Took 0.17 sec.
#
# Parsed weather for Amsterdam since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Athina since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Berlin since 2023-06-12 till 2023-06-19.
# Took 0.18 sec.
#
# Parsed weather for Gdansk since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Kraków since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for London since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Madrid since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Marseille since 2023-06-12 till 2023-06-19.
# Took 0.18 sec.
#
# Parsed weather for Milano since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for München since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Napoli since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for Paris since 2023-06-12 till 2023-06-19.
# Took 0.17 sec.
#
# Parsed weather for Sevilla since 2023-06-12 till 2023-06-19.
# Took 0.17 sec.
#
# Parsed weather for Stockholm since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Tallinn since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Varna since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for Wien since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Albuquerque since 2023-06-12 till 2023-06-19.
# Took 0.19 sec.
#
# Parsed weather for Atlanta since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Chicago since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Columbus since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for Dallas since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Denver since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Houston since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Los Angeles since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for New York since 2023-06-12 till 2023-06-19.
# Took 0.21 sec.
#
# Parsed weather for Phoenix-Mesa since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Salt Lake City since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for San Francisco since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Tampa since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Bellevue-SE 12th St since 2023-06-12 till 2023-06-19.
# Took 0.17 sec.
#
# Parsed weather for DARRINGTON - FIR ST (Darrington High School) since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for KENT - JAMES & CENTRAL since 2023-06-12 till 2023-06-19.
# Took 0.17 sec.
#
# Parsed weather for LAKE FOREST PARK TOWNE CENTER since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for MARYSVILLE - 7TH AVE (Marysville Junior High) since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for NORTH BEND - NORTH BEND WAY since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for SEATTLE - BEACON HILL since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for SEATTLE - DUWAMISH since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for SEATTLE - SOUTH PARK #2 since 2023-06-12 till 2023-06-19.
# Took 0.18 sec.
#
# Parsed weather for Seattle-10th & Weller since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for TACOMA - ALEXANDER AVE since 2023-06-12 till 2023-06-19.
# Took 0.17 sec.
#
# Parsed weather for TACOMA - L STREET since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for Tacoma-S 36th St since 2023-06-12 till 2023-06-19.
# Took 0.15 sec.
#
# Parsed weather for Tukwila Allentown since 2023-06-12 till 2023-06-19.
# Took 0.16 sec.
#
# Parsed weather for Tulalip-Totem Beach Rd since 2023-06-12 till 2023-06-19.
# Took 0.18 sec.
#
# ----------------------------------------------------------------
# Parsed new weather data for ALL cities up to 2023-06-12.
# Took 9.51 sec.

# %%
df_weather_update
# Out:
#                   city_name       date  temperature_max  temperature_min  \
# 0               Albuquerque 2023-06-12             31.1             14.1
# 1               Albuquerque 2023-06-13             29.8             12.3
# 2               Albuquerque 2023-06-14             31.6             15.6
# 3               Albuquerque 2023-06-15             32.5             16.9
# 4               Albuquerque 2023-06-16             32.3             15.4
# ..                      ...        ...              ...              ...
# 459  Tulalip-Totem Beach Rd 2023-06-15             20.3              8.3
# 460  Tulalip-Totem Beach Rd 2023-06-16             18.9             11.2
# 461  Tulalip-Totem Beach Rd 2023-06-17             18.1             10.1
# 462  Tulalip-Totem Beach Rd 2023-06-18             13.6              8.5
# 463  Tulalip-Totem Beach Rd 2023-06-19             14.6              7.6
#
#      precipitation_sum  rain_sum  snowfall_sum  precipitation_hours  \
# 0                  0.0      0.00           0.0                  0.0
# 1                  0.0      0.00           0.0                  0.0
# 2                  0.0      0.00           0.0                  0.0
# 3                  0.0      0.00           0.0                  0.0
# 4                  0.0      0.00           0.0                  0.0
# ..                 ...       ...           ...                  ...
# 459                0.0      0.00           0.0                  0.0
# 460                0.0      0.00           0.0                  0.0
# 461               11.2     11.65           0.0                 19.0
# 462                1.3      0.20           0.0                  4.0
# 463               14.2     12.70           0.0                 24.0
#
#      wind_speed_max  wind_gusts_max  wind_direction_dominant
# 0              29.3            45.0                      200
# 1              26.1            43.9                      219
# 2              22.5            40.7                      251
# 3              45.1            60.1                      232
# 4              49.2            55.8                      245
# ..              ...             ...                      ...
# 459            10.9            20.2                      198
# 460            20.6            35.3                      178
# 461            22.4            31.3                      317
# 462            17.3            25.6                      278
# 463            19.8            34.9                      156
#
# [464 rows x 11 columns]

# %%
df_aq_update.date = pd.to_datetime(df_aq_update.date)
df_weather_update.date = pd.to_datetime(df_weather_update.date)

df_aq_update["unix_time"] = df_aq_update["date"].apply(convert_date_to_unix)
df_weather_update["unix_time"] = df_weather_update["date"].apply(convert_date_to_unix)

# %%
df_aq_update.date = df_aq_update.date.astype(str)
df_weather_update.date = df_weather_update.date.astype(str)

# %% [markdown]
# ---

# %% [markdown]
# ## <span style="color:#ff5f27;">⬆️ Uploading new data to the Feature Store</span>

# %% [markdown]
# ### <span style="color:#ff5f27;"> 🔮 Connecting to Hopsworks Feature Store </span>

# %%
import hopsworks


project = hopsworks.login()
fs = project.get_feature_store() 

air_quality_fg = fs.get_feature_group(
    name = 'air_quality',
    version = 1
)
weather_fg = fs.get_feature_group(
    name = 'weather',
    version = 1
)
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://35.231.25.90:443/p/119
# Connected. Call `.close()` to terminate connection gracefully.

# %%
air_quality_fg.insert(df_aq_update, write_options={"wait_for_job": False})
# Out:
# 2023-06-12 10:48:41,458 INFO: 	1 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://35.231.25.90:443/p/119/fs/67/fg/15
# Uploading Dataframe: 0.00% |          | Rows 0/495 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: air_quality_1_offline_fg_backfill
# Job started successfully, you can follow the progress at
# https://35.231.25.90/p/119/jobs/named/air_quality_1_offline_fg_backfill/executions
# (<hsfs.core.job.Job at 0x7f375772c520>,
#  {
#    "statistics": {
#      "evaluated_expectations": 1,
#      "successful_expectations": 1,
#      "unsuccessful_expectations": 0,
#      "success_percent": 100.0
#    },
#    "meta": {
#      "great_expectations_version": "0.14.12",
#      "expectation_suite_name": "pmi_data",
#      "run_id": {
#        "run_name": null,
#        "run_time": "2023-06-12T08:48:41.456551+00:00"
#      },
#      "batch_kwargs": {
#        "ge_batch_id": "ee669ff6-08fd-11ee-812d-512b762ac0f0"
#      },
#      "batch_markers": {},
#      "batch_parameters": {},
#      "validation_time": "20230612T084841.456043Z",
#      "expectation_suite_meta": {
#        "great_expectations_version": "0.14.12"
#      }
#    },
#    "success": true,
#    "results": [
#      {
#        "meta": {
#          "ingestionResult": "INGESTED",
#          "validationTime": "2023-06-12T08:48:41.000456Z"
#        },
#        "exception_info": {
#          "raised_exception": false,
#          "exception_message": null,
#          "exception_traceback": null
#        },
#        "success": true,
#        "result": {
#          "element_count": 495,
#          "missing_count": 0,
#          "missing_percent": 0.0,
#          "unexpected_count": 0,
#          "unexpected_percent": 0.0,
#          "unexpected_percent_total": 0.0,
#          "unexpected_percent_nonmissing": 0.0,
#          "partial_unexpected_list": []
#        },
#        "expectation_config": {
#          "meta": {
#            "expectationId": 2
#          },
#          "kwargs": {
#            "column": "pm2_5",
#            "min_value": 0.0,
#            "max_value": 1000.0
#          },
#          "expectation_type": "expect_column_values_to_be_between"
#        }
#      }
#    ],
#    "evaluation_parameters": {}
#  })

# %%
weather_fg.insert(df_weather_update, write_options={"wait_for_job": False})
# Out:
# Uploading Dataframe: 0.00% |          | Rows 0/464 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: weather_1_offline_fg_backfill
# Job started successfully, you can follow the progress at
# https://35.231.25.90/p/119/jobs/named/weather_1_offline_fg_backfill/executions
# (<hsfs.core.job.Job at 0x7f37804d32e0>, None)
